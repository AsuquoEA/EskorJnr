# %%
import pandas as pd 
import numpy as py 
import matplotlib.pylab as pt
import seaborn as sn

# %%
el = pd.read_csv('2019Election .csv')

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN
# 0       Abia   85058  219698  212   720   88
# 1    Adamawa  378078  410266  282   109  162
# 2  Akwa Ibom  175429  395832  222   118   95
# 3    Anambra   33298  524738  124  4091   45
# 4     Bauchi  798428  209313  183   112   46

# %%
el.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STATE   37 non-null     object
#  1   APC     37 non-null     int64
#  2   PDP     37 non-null     int64
#  3   AAC     37 non-null     int64
#  4   YPP     37 non-null     int64
#  5   ANN     37 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.9+ KB

# %%
el.describe()
# Out:
#                 APC            PDP          AAC          YPP          ANN
# count  3.700000e+01      37.000000    37.000000    37.000000    37.000000
# mean   4.105905e+05  304404.810811   917.648649   591.513514   453.486486
# std    3.261894e+05  141324.186034  1745.744926  1138.039460  1166.531531
# min    3.329800e+04   50763.000000    75.000000    36.000000    24.000000
# 25%    1.754290e+05  209313.000000   186.000000    78.000000    78.000000
# 50%    3.249060e+05  289895.000000   268.000000   189.000000   119.000000
# 75%    4.979140e+05  374743.000000   416.000000   553.000000   311.000000
# max    1.464768e+06  649612.000000  8910.000000  5733.000000  6946.000000

# %%
el.tail()
# Out:
#       STATE     APC     PDP  AAC  YPP  ANN
# 32   Rivers  150710  473971  372  415  365
# 33   Sokoto  490333  361604  181   84  124
# 34   Taraba  324906  374743  116   80   35
# 35     Yobe  497914   50763  137   36   37
# 36  Zamfara  438682  125423  186   44   24

# %%
el['Total_Votes'] = election['APC']+ election['PDP']+ election['AAC']+ election['YPP']+ election['APC']
el
# Out:
#           STATE      APC     PDP   AAC   YPP   ANN  Total_Votes
# 0          Abia    85058  219698   212   720    88       390746
# 1       Adamawa   378078  410266   282   109   162      1166813
# 2     Akwa Ibom   175429  395832   222   118    95       747030
# 3       Anambra    33298  524738   124  4091    45       595549
# 4        Bauchi   798428  209313   183   112    46      1806464
# 5       Bayelsa   118821  197933   126    50    37       435751
# 6         Benue   347668  356817   309   557   201      1053019
# 7         Borno   836496   71788   269    78    29      1745127
# 8   Cross River   117302  295737   242   217    88       530800
# 9         Delta   221292  594068  1626   497   320      1038775
# 10       Ebonyi    90726  258573   205   192   683       440422
# 11          Edo   267842  275691  3106   531   273       815012
# 12        Ekiti   219231  154032   400    68    88       592962
# 13        Enugu    54423  355553   219  1379   141       465997
# ...

# %%
del el['Total_Votes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Votes'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total
# 0       Abia   85058  219698  212   720   88   696522
# 1    Adamawa  378078  410266  282   109  162  1955710
# 2  Akwa Ibom  175429  395832  222   118   95  1318726
# 3    Anambra   33298  524738  124  4091   45  1157845
# 4     Bauchi  798428  209313  183   112   46  2814546

# %%
del el['Total']

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN
# 0       Abia   85058  219698  212   720   88
# 1    Adamawa  378078  410266  282   109  162
# 2  Akwa Ibom  175429  395832  222   118   95
# 3    Anambra   33298  524738  124  4091   45
# 4     Bauchi  798428  209313  183   112   46

# %%
el['Total'] = el['APC'] + el['PDP'] +el['AAC'] +el['YPP'] +el['ANN']
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total
# 0       Abia   85058  219698  212   720   88   305776
# 1    Adamawa  378078  410266  282   109  162   788897
# 2  Akwa Ibom  175429  395832  222   118   95   571696
# 3    Anambra   33298  524738  124  4091   45   562296
# 4     Bauchi  798428  209313  183   112   46  1008082

# %%
el['% APC'] = el['APC'] / el['Total']

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC
# 0       Abia   85058  219698  212   720   88   305776  0.278171
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027

# %%
el['% PDP'] = el['PDP']/el['Total']

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP
# 0       Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635

# %%
el['% AAC'] = el['AAC']/el['Total']
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP  \
# 0       Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635
#
#       % AAC
# 0  0.000693
# 1  0.000357
# 2  0.000388
# 3  0.000221
# 4  0.000182

# %%
el['% YPP'] = el['YPP']/el['Total']
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP  \
# 0       Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635
#
#       % AAC     % YPP
# 0  0.000693  0.002355
# 1  0.000357  0.000138
# 2  0.000388  0.000206
# 3  0.000221  0.007276
# 4  0.000182  0.000111

# %%
el['% ANN'] = el['ANN']/el['Total']
el.head(9)
# Out:
#          STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP  \
# 0         Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1      Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2    Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3      Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4       Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635
# 5      Bayelsa  118821  197933  126    50   37   316967  0.374869  0.624459
# 6        Benue  347668  356817  309   557  201   705552  0.492760  0.505727
# 7        Borno  836496   71788  269    78   29   908660  0.920582  0.079004
# 8  Cross River  117302  295737  242   217   88   413586  0.283622  0.715056
#
#       % AAC     % YPP     % ANN
# 0  0.000693  0.002355  0.000288
# 1  0.000357  0.000138  0.000205
# 2  0.000388  0.000206  0.000166
# 3  0.000221  0.007276  0.000080
# 4  0.000182  0.000111  0.000046
# ...

# %%
Total_number_of_votes = el['Total'].sum()
Total_number_of_votes
# Out:
# 26527443

# %%
Total_number_of_APC_votes = el['APC'].sum()
Total_number_of_APC_votes
# Out:
# 15191847

# %%
Total_number_of_PDP_votes = el['PDP'].sum()
Total_number_of_PDP_votes
# Out:
# 11262978

# %%
Total_number_of_AAC_votes = el['AAC'].sum()
Total_number_of_AAC_votes
# Out:
# 33953

# %%
Total_number_of_YPP_votes = el['YPP'].sum()
Total_number_of_YPP_votes
# Out:
# 21886

# %%
Total_number_of_ANN_votes = el['ANN'].sum()
Total_number_of_ANN_votes
# Out:
# 16779

# %%
el['APC'].min()
# Out:
# 33298

# %%
el['PDP'].min()
# Out:
# 50763

# %%
el['AAC'].min()
# Out:
# 75

# %%
el['Total% votes'] = el['% APC']+el['% PDP']+ el['% AAC']+el['% YPP']+el['% ANN']
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP  \
# 0       Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635
#
#       % AAC     % YPP     % ANN  Total% votes
# 0  0.000693  0.002355  0.000288           1.0
# 1  0.000357  0.000138  0.000205           1.0
# 2  0.000388  0.000206  0.000166           1.0
# 3  0.000221  0.007276  0.000080           1.0
# 4  0.000182  0.000111  0.000046           1.0

# %%
del el['Total% votes']

# %%
el.head()
# Out:
#        STATE     APC     PDP  AAC   YPP  ANN    Total     % APC     % PDP  \
# 0       Abia   85058  219698  212   720   88   305776  0.278171  0.718493
# 1    Adamawa  378078  410266  282   109  162   788897  0.479249  0.520050
# 2  Akwa Ibom  175429  395832  222   118   95   571696  0.306857  0.692382
# 3    Anambra   33298  524738  124  4091   45   562296  0.059218  0.933206
# 4     Bauchi  798428  209313  183   112   46  1008082  0.792027  0.207635
#
#       % AAC     % YPP     % ANN
# 0  0.000693  0.002355  0.000288
# 1  0.000357  0.000138  0.000205
# 2  0.000388  0.000206  0.000166
# 3  0.000221  0.007276  0.000080
# 4  0.000182  0.000111  0.000046

# %%
ax = el.plot(kind='bar', x = 'STATE', y = '% APC', title = '2019 presidential election', figsize = (30,20))

ax.set_xlabel ('States')
ax.set_ylabel ('%APC')
# Out:
# Text(0, 0.5, '%APC')

# %%
ax = el.plot(kind='line', x = 'STATE', y = '% PDP', title = '2019 presidential election', figsize = (30,20))

ax.set_xlabel ('States')
ax.set_ylabel ('%APC')
# Out:
# Text(0, 0.5, '%APC')

# %%
#To plot graph

ax = el.plot(kind='kde', x = 'STATE', y = 'Total', title='2019 Nigeria presidential election', figsize = (30,20))

#To label axis x and y:
ax.set_xlabel('States')
ax.set_ylabel('number of votes')
# Out:
# Text(0, 0.5, 'number of votes')

# %%
ax = el.plot(kind='line', x='STATE', y='% PDP', title = 'PDP votes', figsize = (30,10))

ax.set_xlabel ('States')
ax.set_ylabel ('PDP votes')
# Out:
# Text(0, 0.5, 'PDP votes')
