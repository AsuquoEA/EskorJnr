# %% [markdown]
# ## Essential import conventions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
import matplotlib.ticker as ticker

# %% [markdown]
# ## Read .csv file

# %%
EM = pd.read_csv('Canada Energy Production.csv')

# %% [markdown]
# ## Depict top 5 rows and last 5 rows

# %%
EM.head()
# Out:
#   domestic energy production in Canada    Value  Year Units
# 0               Coal and coal products  1440552  2000    TJ
# 1               Coal and coal products  1462923  2001    TJ
# 2               Coal and coal products  1363499  2002    TJ
# 3               Coal and coal products  1266862  2003    TJ
# 4               Coal and coal products  1347317  2004    TJ

# %%
EM.tail()
# Out:
#     domestic energy production in Canada  Value  Year Units
# 195                                 Heat      0  2020    TJ
# 196                                 Heat      0  2021    TJ
# 197                                 Heat      0  2022    TJ
# 198                                 Heat      0  2023    TJ
# 199                                 Heat      0  2024    TJ

# %% [markdown]
# ## Check for nulls

# %%
EM.isna()
# Out:
#      domestic energy production in Canada  Value   Year  Units
# 0                                   False  False  False  False
# 1                                   False  False  False  False
# 2                                   False  False  False  False
# 3                                   False  False  False  False
# 4                                   False  False  False  False
# ..                                    ...    ...    ...    ...
# 195                                 False  False  False  False
# 196                                 False  False  False  False
# 197                                 False  False  False  False
# 198                                 False  False  False  False
# 199                                 False  False  False  False
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Check for data type

# %%
EM.dtypes
# Out:
# domestic energy production in Canada    object
# Value                                    int64
# Year                                     int64
# Units                                   object
# dtype: object

# %% [markdown]
# ## Rename first column

# %%
EM.rename(columns={"domestic energy production in Canada": "Energy Mix"}, inplace=True)

# %%
EM.dtypes
# Out:
# Energy Mix    object
# Value          int64
# Year           int64
# Units         object
# dtype: object

# %% [markdown]
# ## Plot data

# %%
plt.figure(figsize=(12,7))
for mix in EM['Energy Mix'].unique():
    subset = EM[EM['Energy Mix'] == mix]
    plt.bar(subset['Year'], subset['Value'], label=mix)
plt.title('Domestic Energy Production in Canada by Energy Type')
plt.xlabel('Year')
plt.ylabel(EM['Units'].iloc[0])
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Turn off scientific notation on the y-axis
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ## For coal

# %%
# Filter for coal only
coal = EM[EM['Energy Mix'] == 'Coal and coal products']

plt.figure(figsize=(10,6))
plt.plot(coal['Year'], coal['Value'], marker='o', linewidth=2, color='brown')

plt.title('Domestic Energy Production in Canada – Coal and Coal Products')
plt.xlabel('Year')
plt.ylabel(coal['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ## For oil

# %%
# Filter for Oil only
Oil = EM[EM['Energy Mix'] == 'Primary oil']

plt.figure(figsize=(10,6))
plt.plot(Oil['Year'], Oil['Value'], marker='o', linewidth=2, color='black')

plt.title('Domestic Energy Production in Canada – Oil')
plt.xlabel('Year')
plt.ylabel(Oil['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ## Natural gas

# %%
# Filter for Natural gas only
Natural_gas = EM[EM['Energy Mix'] == 'Natural gas']

plt.figure(figsize=(10,6))
plt.plot(Natural_gas['Year'], Natural_gas['Value'], marker='o', linewidth=2, color='blue')

plt.title('Domestic Energy Production in Canada – Natural gas')
plt.xlabel('Year')
plt.ylabel(Natural_gas['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ## For Nuclear

# %%
# Filter for Nuclear only
Nuclear = EM[EM['Energy Mix'] == 'Nuclear']

plt.figure(figsize=(10,6))
plt.plot(Nuclear['Year'], Nuclear['Value'], marker='o', linewidth=2, color='red')

plt.title('Domestic Energy Production in Canada – Nuclear')
plt.xlabel('Year')
plt.ylabel(Nuclear['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ## Hydro

# %%
# Filter for Hydro only
Hydro = EM[EM['Energy Mix'] == 'Hydropower']

plt.figure(figsize=(10,6))
plt.plot(Hydro['Year'], Hydro['Value'], marker='o', linewidth=2, color='blue')

plt.title('Domestic Energy Production in Canada – Hydro')
plt.xlabel('Year')
plt.ylabel(Hydro['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %%
# Filter for coal only
Renewables = EM[EM['Energy Mix'] == 'Solar, wind and other renewables']

plt.figure(figsize=(10,6))
plt.plot(Renewables['Year'],Renewables['Value'], marker='o', linewidth=2, color='green')

plt.title('Domestic Energy Production in Canada – Renewables (Solar, wind)')
plt.xlabel('Year')
plt.ylabel(Renewables['Units'].iloc[0])
plt.grid(True, linestyle='--', alpha=0.7)

# Remove exponential notation
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()
