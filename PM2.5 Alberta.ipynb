# %% [markdown]
# #### Import libaries

# %%
import pandas as pd 
import numpy as np
import seaborn as sn 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read data into pandas

# %%
pm = pd.read_csv('PM2.5 Alberta.csv')

# %% [markdown]
# #### View first 5 rows of data

# %%
pm.head()
# Out:
#    Category  Provincial Average  10th Percentile  90th Percentile  Calgary  \
# 0      2000                 8.1              6.3             10.8     10.1
# 1      2001                 7.2              3.3              9.7      9.5
# 2      2002                 5.0              2.9              6.9      6.3
# 3      2003                 5.6              3.2              7.7      8.1
# 4      2004                 4.9              3.2              6.7      6.4
#
#    Edmonton  Fort McMurray  Grande Prairie  Lethbridge  Medicine Hat  \
# 0      11.3            6.5             NaN         NaN           NaN
# 1      10.2            6.9             NaN         NaN           NaN
# 2       6.9            4.7             NaN         NaN           NaN
# 3       7.3            3.6             NaN         NaN           NaN
# 4       6.5            4.2             NaN         4.1           3.1
#
#    Red Deer  CAAQS
# 0       NaN    8.8
# 1       8.6    8.8
# 2       5.5    8.8
# 3       5.7    8.8
# 4       5.0    8.8

# %% [markdown]
# #### View last 5 rows of data

# %%
pm.tail()
# Out:
#     Category  Provincial Average  10th Percentile  90th Percentile  Calgary  \
# 17      2017                 6.4              4.5              8.0      7.9
# 18      2018                 8.9              6.6             11.6     11.2
# 19      2019                 6.3              4.7              8.1      7.1
# 20      2020                 5.2              4.0              6.7      6.3
# 21      2021                 7.2              5.5              8.7      8.4
#
#     Edmonton  Fort McMurray  Grande Prairie  Lethbridge  Medicine Hat  \
# 17       7.9            5.9             6.7         7.5           5.8
# 18      10.2            7.6             9.9         9.3           6.9
# 19       7.6            6.4             6.9         5.4           4.6
# 20       6.2            5.5             4.9         5.3           5.2
# 21       8.9            7.0             6.1         7.0           7.2
#
#     Red Deer  CAAQS
# 17       6.8    8.8
# 18       9.5    8.8
# 19       6.9    8.8
# 20       5.2    8.8
# 21       7.4    8.8

# %% [markdown]
# #### View the shape of the data

# %%
pm.shape
# Out:
# (13, 12)

# %% [markdown]
# #### To show the number of duplicate value present

# %%
pm.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Drop duplicates in data

# %%
pm = pm.drop_duplicates()
pm
# Out:
#     Category  Provincial Average  10th Percentile  90th Percentile  Calgary  \
# 0       2000                 8.1              6.3             10.8     10.1
# 1       2001                 7.2              3.3              9.7      9.5
# 2       2002                 5.0              2.9              6.9      6.3
# 3       2003                 5.6              3.2              7.7      8.1
# 4       2004                 4.9              3.2              6.7      6.4
# 5       2005                 4.5              3.3              6.5      5.5
# 6       2006                 5.0              3.8              6.9      6.6
# 7       2007                 4.8              3.4              7.0      5.7
# 8       2008                 4.9              3.4              6.9      5.7
# 9       2009                 5.5              3.7              8.5      9.0
# 10      2010                 8.2              4.6             14.4     11.4
# 11      2011                 6.9              3.4             10.3     10.9
# 12      2012                 6.9              4.6              9.4     10.0
# 13      2013                 6.4              3.6              8.6      8.1
# 14      2014                 7.0              4.3              9.1      8.2
# 15      2015                 7.1              4.1              9.4      8.1
# 16      2016                 6.6              3.9              9.7      5.2
# 17      2017                 6.4              4.5              8.0      7.9
# 18      2018                 8.9              6.6             11.6     11.2
# 19      2019                 6.3              4.7              8.1      7.1
# 20      2020                 5.2              4.0              6.7      6.3
# 21      2021                 7.2              5.5              8.7      8.4
#
#     Edmonton  Fort McMurray  Grande Prairie  Lethbridge  Medicine Hat  \
# 0       11.3            6.5             NaN         NaN           NaN
# 1       10.2            6.9             NaN         NaN           NaN
# 2        6.9            4.7             NaN         NaN           NaN
# 3        7.3            3.6             NaN         NaN           NaN
# 4        6.5            4.2             NaN         4.1           3.1
# 5        5.4            3.6             4.6         3.3           3.1
# 6        5.7            4.3             5.2         4.0           3.5
# 7        5.3            4.6             4.0         3.6           3.5
# 8        6.0            4.9             4.1         3.6           3.4
# 9        7.9            4.0             4.8         3.8           NaN
# 10      14.8            4.6            10.8         7.7           NaN
# 11       9.7            8.2             8.4         6.6           7.8
# 12       8.7            6.0             6.5         NaN           9.4
# 13       8.7            6.4             6.3         7.0           NaN
# 14       9.8            8.0             8.2         7.1           4.8
# 15       9.0            8.5             6.4         8.2           6.6
# 16       7.3           19.0             6.1         4.8           4.0
# 17       7.9            5.9             6.7         7.5           5.8
# 18      10.2            7.6             9.9         9.3           6.9
# 19       7.6            6.4             6.9         5.4           4.6
# 20       6.2            5.5             4.9         5.3           5.2
# 21       8.9            7.0             6.1         7.0           7.2
#
#     Red Deer  CAAQS
# 0        NaN    8.8
# 1        8.6    8.8
# 2        5.5    8.8
# 3        5.7    8.8
# 4        5.0    8.8
# 5        4.5    8.8
# 6        5.4    8.8
# 7        4.2    8.8
# 8        4.4    8.8
# 9        8.6    8.8
# 10      16.2    8.8
# 11      13.7    8.8
# 12      10.2    8.8
# 13      10.4    8.8
# 14       7.1    8.8
# 15       8.8    8.8
# 16       5.7    8.8
# 17       6.8    8.8
# 18       9.5    8.8
# 19       6.9    8.8
# 20       5.2    8.8
# 21       7.4    8.8

# %% [markdown]
# #### Removing Null values (Nan)

# %%
pm.dropna(inplace=True)
pm
# Out:
#     Category  Provincial Average  10th Percentile  90th Percentile  Calgary  \
# 5       2005                 4.5              3.3              6.5      5.5
# 6       2006                 5.0              3.8              6.9      6.6
# 7       2007                 4.8              3.4              7.0      5.7
# 8       2008                 4.9              3.4              6.9      5.7
# 11      2011                 6.9              3.4             10.3     10.9
# 14      2014                 7.0              4.3              9.1      8.2
# 15      2015                 7.1              4.1              9.4      8.1
# 16      2016                 6.6              3.9              9.7      5.2
# 17      2017                 6.4              4.5              8.0      7.9
# 18      2018                 8.9              6.6             11.6     11.2
# 19      2019                 6.3              4.7              8.1      7.1
# 20      2020                 5.2              4.0              6.7      6.3
# 21      2021                 7.2              5.5              8.7      8.4
#
#     Edmonton  Fort McMurray  Grande Prairie  Lethbridge  Medicine Hat  \
# 5        5.4            3.6             4.6         3.3           3.1
# 6        5.7            4.3             5.2         4.0           3.5
# 7        5.3            4.6             4.0         3.6           3.5
# 8        6.0            4.9             4.1         3.6           3.4
# 11       9.7            8.2             8.4         6.6           7.8
# 14       9.8            8.0             8.2         7.1           4.8
# 15       9.0            8.5             6.4         8.2           6.6
# 16       7.3           19.0             6.1         4.8           4.0
# 17       7.9            5.9             6.7         7.5           5.8
# 18      10.2            7.6             9.9         9.3           6.9
# 19       7.6            6.4             6.9         5.4           4.6
# 20       6.2            5.5             4.9         5.3           5.2
# 21       8.9            7.0             6.1         7.0           7.2
#
#     Red Deer  CAAQS
# 5        4.5    8.8
# 6        5.4    8.8
# 7        4.2    8.8
# 8        4.4    8.8
# 11      13.7    8.8
# 14       7.1    8.8
# 15       8.8    8.8
# 16       5.7    8.8
# 17       6.8    8.8
# 18       9.5    8.8
# 19       6.9    8.8
# 20       5.2    8.8
# 21       7.4    8.8

# %% [markdown]
# #### Dropping unnecessary columns

# %%
to_drop = ['10th Percentile', '90th Percentile']

pm.drop(to_drop, inplace=True, axis=1)

# %%
pm
# Out:
#     Category  Provincial Average  Calgary  Edmonton  Fort McMurray  \
# 5       2005                 4.5      5.5       5.4            3.6
# 6       2006                 5.0      6.6       5.7            4.3
# 7       2007                 4.8      5.7       5.3            4.6
# 8       2008                 4.9      5.7       6.0            4.9
# 11      2011                 6.9     10.9       9.7            8.2
# 14      2014                 7.0      8.2       9.8            8.0
# 15      2015                 7.1      8.1       9.0            8.5
# 16      2016                 6.6      5.2       7.3           19.0
# 17      2017                 6.4      7.9       7.9            5.9
# 18      2018                 8.9     11.2      10.2            7.6
# 19      2019                 6.3      7.1       7.6            6.4
# 20      2020                 5.2      6.3       6.2            5.5
# 21      2021                 7.2      8.4       8.9            7.0
#
#     Grande Prairie  Lethbridge  Medicine Hat  Red Deer  CAAQS
# 5              4.6         3.3           3.1       4.5    8.8
# 6              5.2         4.0           3.5       5.4    8.8
# 7              4.0         3.6           3.5       4.2    8.8
# 8              4.1         3.6           3.4       4.4    8.8
# 11             8.4         6.6           7.8      13.7    8.8
# 14             8.2         7.1           4.8       7.1    8.8
# 15             6.4         8.2           6.6       8.8    8.8
# 16             6.1         4.8           4.0       5.7    8.8
# 17             6.7         7.5           5.8       6.8    8.8
# 18             9.9         9.3           6.9       9.5    8.8
# 19             6.9         5.4           4.6       6.9    8.8
# 20             4.9         5.3           5.2       5.2    8.8
# 21             6.1         7.0           7.2       7.4    8.8

# %% [markdown]
# #### To rename columns of the dataframe

# %%
new_name = {'Category':'Year'}

pm.rename(columns=new_name, inplace= True)

# %%
pm
# Out:
#     Year  Provincial Average  Calgary  Edmonton  Fort McMurray  \
# 5   2005                 4.5      5.5       5.4            3.6
# 6   2006                 5.0      6.6       5.7            4.3
# 7   2007                 4.8      5.7       5.3            4.6
# 8   2008                 4.9      5.7       6.0            4.9
# 11  2011                 6.9     10.9       9.7            8.2
# 14  2014                 7.0      8.2       9.8            8.0
# 15  2015                 7.1      8.1       9.0            8.5
# 16  2016                 6.6      5.2       7.3           19.0
# 17  2017                 6.4      7.9       7.9            5.9
# 18  2018                 8.9     11.2      10.2            7.6
# 19  2019                 6.3      7.1       7.6            6.4
# 20  2020                 5.2      6.3       6.2            5.5
# 21  2021                 7.2      8.4       8.9            7.0
#
#     Grande Prairie  Lethbridge  Medicine Hat  Red Deer  CAAQS
# 5              4.6         3.3           3.1       4.5    8.8
# 6              5.2         4.0           3.5       5.4    8.8
# 7              4.0         3.6           3.5       4.2    8.8
# 8              4.1         3.6           3.4       4.4    8.8
# 11             8.4         6.6           7.8      13.7    8.8
# 14             8.2         7.1           4.8       7.1    8.8
# 15             6.4         8.2           6.6       8.8    8.8
# 16             6.1         4.8           4.0       5.7    8.8
# 17             6.7         7.5           5.8       6.8    8.8
# 18             9.9         9.3           6.9       9.5    8.8
# 19             6.9         5.4           4.6       6.9    8.8
# 20             4.9         5.3           5.2       5.2    8.8
# 21             6.1         7.0           7.2       7.4    8.8

# %% [markdown]
# #### Resetting index from 0 to 100

# %%
pm.reset_index(inplace=True)

# %%
pm
# Out:
#     index  Year  Provincial Average  Calgary  Edmonton  Fort McMurray  \
# 0       5  2005                 4.5      5.5       5.4            3.6
# 1       6  2006                 5.0      6.6       5.7            4.3
# 2       7  2007                 4.8      5.7       5.3            4.6
# 3       8  2008                 4.9      5.7       6.0            4.9
# 4      11  2011                 6.9     10.9       9.7            8.2
# 5      14  2014                 7.0      8.2       9.8            8.0
# 6      15  2015                 7.1      8.1       9.0            8.5
# 7      16  2016                 6.6      5.2       7.3           19.0
# 8      17  2017                 6.4      7.9       7.9            5.9
# 9      18  2018                 8.9     11.2      10.2            7.6
# 10     19  2019                 6.3      7.1       7.6            6.4
# 11     20  2020                 5.2      6.3       6.2            5.5
# 12     21  2021                 7.2      8.4       8.9            7.0
#
#     Grande Prairie  Lethbridge  Medicine Hat  Red Deer  CAAQS
# 0              4.6         3.3           3.1       4.5    8.8
# 1              5.2         4.0           3.5       5.4    8.8
# 2              4.0         3.6           3.5       4.2    8.8
# 3              4.1         3.6           3.4       4.4    8.8
# 4              8.4         6.6           7.8      13.7    8.8
# 5              8.2         7.1           4.8       7.1    8.8
# 6              6.4         8.2           6.6       8.8    8.8
# 7              6.1         4.8           4.0       5.7    8.8
# 8              6.7         7.5           5.8       6.8    8.8
# 9              9.9         9.3           6.9       9.5    8.8
# 10             6.9         5.4           4.6       6.9    8.8
# 11             4.9         5.3           5.2       5.2    8.8
# 12             6.1         7.0           7.2       7.4    8.8

# %% [markdown]
# #### Basic information about the data

# %%
pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   level_0             13 non-null     int64
#  1   index               13 non-null     int64
#  2   Year                13 non-null     int64
#  3   Provincial Average  13 non-null     float64
#  4   Calgary             13 non-null     float64
#  5   Edmonton            13 non-null     float64
#  6   Fort McMurray       13 non-null     float64
#  7   Grande Prairie      13 non-null     float64
#  8   Lethbridge          13 non-null     float64
#  9   Medicine Hat        13 non-null     float64
#  10  Red Deer            13 non-null     float64
#  11  CAAQS               13 non-null     float64
# dtypes: float64(9), int64(3)
# memory usage: 1.3 KB

# %% [markdown]
# #### Descriptive statistics

# %%
pm.describe()
# Out:
#         level_0      index         Year  Provincial Average    Calgary  \
# count  13.00000  13.000000    13.000000           13.000000  13.000000
# mean    6.00000  13.615385  2013.615385            6.215385   7.446154
# std     3.89444   5.605629     5.605629            1.272037   1.941054
# min     0.00000   5.000000  2005.000000            4.500000   5.200000
# 25%     3.00000   8.000000  2008.000000            5.000000   5.700000
# 50%     6.00000  15.000000  2015.000000            6.400000   7.100000
# 75%     9.00000  18.000000  2018.000000            7.000000   8.200000
# max    12.00000  21.000000  2021.000000            8.900000  11.200000
#
#         Edmonton  Fort McMurray  Grande Prairie  Lethbridge  Medicine Hat  \
# count  13.000000      13.000000       13.000000   13.000000     13.000000
# mean    7.615385       7.192308        6.269231    5.823077      5.107692
# std     1.781781       3.888115        1.774065    1.941715      1.613723
# min     5.300000       3.600000        4.000000    3.300000      3.100000
# 25%     6.000000       4.900000        4.900000    4.000000      3.500000
# 50%     7.600000       6.400000        6.100000    5.400000      4.800000
# 75%     9.000000       8.000000        6.900000    7.100000      6.600000
# max    10.200000      19.000000        9.900000    9.300000      7.800000
#
#         Red Deer         CAAQS
# count  13.000000  1.300000e+01
# mean    6.892308  8.800000e+00
# std     2.626614  1.848891e-15
# min     4.200000  8.800000e+00
# 25%     5.200000  8.800000e+00
# 50%     6.800000  8.800000e+00
# 75%     7.400000  8.800000e+00
# max    13.700000  8.800000e+00

# %% [markdown]
# #### To find the number of unique values in a particular column

# %%
pm['Year'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2011, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021])

# %%
pm['Calgary'].unique()
# Out:
# array([ 5.5,  6.6,  5.7, 10.9,  8.2,  8.1,  5.2,  7.9, 11.2,  7.1,  6.3,
#         8.4])

# %% [markdown]
# #### Plotting multiple lines

# %%
plt.plot(pm['Year'], pm['Calgary'], label='Calgary')
plt.plot(pm['Year'], pm['Edmonton'], label='Edmonton')
plt.plot(pm['Year'], pm['Fort McMurray'], label='Fort McMurray')
plt.plot(pm['Year'], pm['Grande Prairie'], label='Grande Prairie')
plt.plot(pm['Year'], pm['Lethbridge'], label='Lethbridge')
plt.plot(pm['Year'], pm['Medicine Hat'], label='Medicine Hat')
plt.plot(pm['Year'], pm['Red Deer'], label='Red Deer')
plt.plot(pm['Year'], pm['CAAQS'],label='CAAQS')


plt.legend()
plt.show()

# %% [markdown]
# #### Drawing Bar Plots (Vertical bar)

# %%
plt.bar(pm['Year'], pm['Calgary'], label='Calgary')

plt.legend()
plt.show()

# %%
plt.bar(pm['Year'], pm['Edmonton'], label='Edmonton')

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Plotting horizontal plot

# %%
plt.barh(pm['Year'], pm['Edmonton'], label='Edmonton')

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Scatter plots

# %%
plt.scatter(pm['Year'], pm['Calgary'])
plt.show()

# %%
plt.scatter(pm['Year'], pm['Edmonton'])
plt.show()

# %% [markdown]
# #### Scatter plots with a trend line or line of best fit

# %%
z = np.polyfit(pm['Year'], pm['Calgary'], 1)
p = np.poly1d(z)


plt.scatter(pm['Year'], pm['Calgary'])
plt.plot(pm['Year'], p(pm['Year']))
plt.show()

# %%
pm.Calgary.describe()
# Out:
# count    13.000000
# mean      7.446154
# std       1.941054
# min       5.200000
# 25%       5.700000
# 50%       7.100000
# 75%       8.200000
# max      11.200000
# Name: Calgary, dtype: float64

# %%
pm.Calgary.hist()
# Out:
# <Axes: >

# %%
pm.Edmonton.hist()
# Out:
# <Axes: >
